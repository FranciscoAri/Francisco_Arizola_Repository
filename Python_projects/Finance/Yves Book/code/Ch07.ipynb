# %% [markdown]
# This python notebook is based on the book "Python for Finance: Mastering Data-Driven Finance" by Yves Hilpisch.

# %% [markdown]
# Elaborated by: Francisco Arizola

# %% [markdown]
# # Part III: Financial Data Science

# %% [markdown]
# ## Chapter 7: Data Visualization

# %% [markdown]
# ### Static 2D Plotting

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# One-Dimensional Data Sets

# We start with a simple plot
np.random.seed(1000)
y = np.random.standard_normal(20)
x = np.arange(len(y))
plt.plot(x, y)

# %%
# With cumsum() one gets the cummulative sum of the data
plt.plot(y.cumsum())

# To plot without a grid
plt.grid(False)

# For equal scaling for the two axis
plt.axis('equal')
# Out:
# (-0.9500000000000001, 19.95, -2.322818663749045, 0.5655085808655865)

# %%
# In addition, one can directly set the minimum and maximum values of each axis by using plt.xlim() and plt.ylim()
plt.plot(y.cumsum())
plt.xlim(-1, 20)
plt.ylim(np.min(y.cumsum()) - 1,
np.max(y.cumsum()) + 1)
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %%
# Adding labels, title and plotting design
plt.figure(figsize=(10, 6))
plt.plot(y.cumsum(), 'b', lw=1.5)
plt.plot(y.cumsum(), 'ro')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple Plot')
# Out:
# Text(0.5, 1.0, 'A Simple Plot')

# %%
# Two-Dimensional Data Sets

# First, we calculate the cumulative sum of the sample data
y = np.random.standard_normal((20, 2)).cumsum(axis=0)

# Now, we once again use plt.plot. It will then automatically interpret the contained data as separate data sets
plt.figure(figsize=(10, 6))
plt.plot(y, lw=1.5)
plt.plot(y, 'ro')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple Plot')
# Out:
# Text(0.5, 1.0, 'A Simple Plot')

# %%
# We can add a legend to better identify the data sets
plt.figure(figsize=(10, 6))
plt.plot(y[:, 0], lw=1.5, label='1st') # Defines labels for the data subsets.
plt.plot(y[:, 1], lw=1.5, label='2nd') # Defines labels for the data subsets.
plt.plot(y, 'ro')
plt.legend(loc=0) # Places a legend in the “best” location
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple Plot')
# Out:
# Text(0.5, 1.0, 'A Simple Plot')

# %%
# Often, data sets show different scalings and the plotting of such data with a single y-scale generally leads to a significant loss of visual information

# Here an example
y[:, 0] = y[:, 0] * 100 # This is just to rescale the first data set

plt.figure(figsize=(10, 6))
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.plot(y[:, 1], lw=1.5, label='2nd')
plt.plot(y, 'ro')
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple Plot')
# Out:
# Text(0.5, 1.0, 'A Simple Plot')

# %%
# There are two basic approaches to resolve this problem through plotting: Two y-axis or two subplots

# Introducing a second y-axis
fig, ax1 = plt.subplots()
plt.plot(y[:, 0], 'b', lw=1.5, label='1st')
plt.plot(y[:, 0], 'ro')
plt.legend(loc=8)
plt.xlabel('index')
plt.ylabel('value 1st')
plt.title('A Simple Plot')
ax2 = ax1.twinx()
plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.plot(y[:, 1], 'ro')
plt.legend(loc=0)
plt.ylabel('value 2nd')
# Out:
# Text(0, 0.5, 'value 2nd')

# %%
# Now, let's consider the option of two separate sub-plots
plt.figure(figsize=(10, 6))
plt.subplot(211)
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.plot(y[:, 0], 'ro')
plt.legend(loc=0)
plt.ylabel('value')
plt.title('A Simple Plot')
plt.subplot(212)
plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.plot(y[:, 1], 'ro')
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
# The subplot option allows to combine different types of graphs
plt.figure(figsize=(10, 6))
plt.subplot(121)
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.plot(y[:, 0], 'ro')
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
plt.title('1st Data Set')
plt.subplot(122)
plt.bar(np.arange(len(y)), y[:, 1], width=0.5,
color='g', label='2nd')
plt.legend(loc=0)
plt.xlabel('index')
plt.title('2nd Data Set')
# Out:
# Text(0.5, 1.0, '2nd Data Set')

# %%
# Scatter plots
y = np.random.standard_normal((1000, 2))

plt.figure(figsize=(10, 6))
plt.plot(y[:, 0], y[:, 1], 'ro')
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# We can also use the plt.scatter function for a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(y[:, 0], y[:, 1], marker='o')
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# Among other things, the plt.scatter() plotting function allows the addition of a third dimension, which can be visualized 
# through different colors and be described by the use of a color bar

c = np.random.randint(0, 10, len(y)) # Third data set

plt.figure(figsize=(10, 6))
plt.scatter(y[:, 0], y[:, 1],
 c=c,
 cmap='coolwarm', # Chooses the color map
 marker='o') # Defines the marker to be a thick dot.
plt.colorbar()
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# Histogram for two data sets
plt.figure(figsize=(10, 6))
plt.hist(y, label=['1st', '2nd'], bins=25)
plt.legend(loc=0)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# Stacking the two data sets
plt.figure(figsize=(10, 6))
plt.hist(y, label=['1st', '2nd'], color=['b', 'g'],
stacked=True, bins=20, alpha=0.5)
plt.legend(loc=0)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# Box plot, perfect for analyzing the characteristics of the data set and comparing data sets
fig, ax = plt.subplots(figsize=(10, 6))
plt.boxplot(y)
plt.setp(ax, xticklabels=['1st', '2nd'])
plt.xlabel('data set')
plt.ylabel('value')
plt.title('Boxplot')
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
# Function definition to highlight the area below the function
def func(x):
    return 0.5 * np.exp(x) + 1
a, b = 0.5, 1.5
x = np.linspace(0, 2)
y = func(x)
Ix = np.linspace(a, b)
Iy = func(Ix)
verts = [(a, 0)] + list(zip(Ix, Iy)) + [(b, 0)]

# %%
# Import the Polygon library
from matplotlib.patches import Polygon

fig, ax = plt.subplots(figsize=(10, 6))
plt.plot(x, y, 'b', linewidth=2)
plt.ylim(bottom=0)
poly = Polygon(verts, facecolor='0.7', edgecolor='0.5') # Plots the polygon (integral area) in gray
ax.add_patch(poly) # Plots the polygon (integral area) in gray
plt.text(0.5 * (a + b), 1, r'$\int_a^b f(x)\mathrm{d}x$', # Notice that it allows for Latex notation
horizontalalignment='center', fontsize=20)
plt.figtext(0.9, 0.075, '$x$')
plt.figtext(0.075, 0.9, '$f(x)$')
ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([func(a), func(b)])
ax.set_yticklabels(('$f(a)$', '$f(b)$'))
# Out:
# [Text(0, 1.824360635350064, '$f(a)$'), Text(0, 3.2408445351690323, '$f(b)$')]

# %% [markdown]
# ### Static 3D Plotting

# %%
# In what follows, the code artificially generates a plot that resembles a volatility surface.
strike = np.linspace(50, 150, 24) # Strike values between 50 and 150
ttm = np.linspace(0.5, 2.5, 24) # Times-to-maturity between 0.5 and 2.5 years

strike, ttm = np.meshgrid(strike, ttm) # Provides a two-dimensional coordinate system out of two one-dimensional ndarray objects

strike[:2].round(1)

iv = (strike - 100) ** 2 / (100 * strike) / ttm

iv[:5, :3]
# Out:
# array([[1.        , 0.76695652, 0.58132045],
#        [0.85185185, 0.65333333, 0.4951989 ],
#        [0.74193548, 0.56903226, 0.43130227],
#        [0.65714286, 0.504     , 0.38201058],
#        [0.58974359, 0.45230769, 0.34283001]])

# %%
# 3D plotting library
from mpl_toolkits.mplot3d import Axes3D

# 3D graph
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d') # Sets up a canvas for 3D plotting
surf = ax.plot_surface(strike, ttm, iv, rstride=2, cstride=2, 
                        cmap=plt.cm.coolwarm, linewidth=0.5,
                        antialiased=True)
ax.set_xlabel('strike')
ax.set_ylabel('time-to-maturity')
ax.set_zlabel('implied volatility')
fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
# Let's plot the same graph but with different line style and viewing angle
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(30, 60) # Sets the viewing angle
ax.scatter(strike, ttm, iv, zdir='z', s=25,
c='b', marker='^')
ax.set_xlabel('strike')
ax.set_ylabel('time-to-maturity')
ax.set_zlabel('implied volatility')
# Out:
# Text(0.5, 0, 'implied volatility')

# %% [markdown]
# ### Interactive 2D Plotting

# %%
# Uncomment the next line if you do not have cufflinks and plotly installed
# !pip install cufflinks plotly

import pandas as pd
import cufflinks as cf 
import plotly.offline as plyo

# Initialize plotly to work in offline mode
plyo.init_notebook_mode(connected=True)

# Optional: if you are using Jupyter Notebook, you might want to enable inline plotting
cf.go_offline()
# Out:
# ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
# The examples that follow rely again on pseudo-random numbers, this time stored in a DataFrame object with DatetimeIndex (i.e., as time series data)
a = np.random.standard_normal((250, 5)).cumsum(axis=0)
index = pd.date_range('2019-1-1',
                    freq='B', #The frequency (“business daily”)
                    periods=len(a))

df = pd.DataFrame(100 + 5 * a, columns=list('abcde'), index=index)

df.head()
# Out:
#                      a           b           c          d           e
# 2019-01-01  109.037535   98.693865  104.474094  96.878857  100.621936
# 2019-01-02  107.598242   97.005738  106.789189  97.966552  100.175313
# 2019-01-03  101.639668  100.332253  103.183500  99.747869  107.902901
# 2019-01-04   98.500363  101.208283  100.966242  94.023898  104.387256
# 2019-01-07   93.941632  103.319168  105.674012  95.891062   86.547934

# %%
# Cufflinks adds a new method to the DataFrame class: df.iplot(). This method uses plotly in the backend to create 
# interactive plots.

plyo.iplot(               # This makes use of the offline (notebook mode) capabilities of plotly
df.iplot(asFigure=True),  # The df.iplot() method is called with parameter asFigure=True to allow for local plotting and embedding.
image='png',              # The image option provides in addition a static bitmap version of the plot. 
filename='ply_01'         # The filename for the bitmap to be saved is specified (the file type extension is added automatically)
)
# Out:
# <div>                            <div id="28115a4b-eab6-42ec-baca-8dd68f479218" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28115a4b-eab6-42ec-baca-8dd68f479218")) {                    Plotly.newPlot(                        "28115a4b-eab6-42ec-baca-8dd68f479218",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"a","text":"","x":["2019-01-01","2019-01-02","2019-01-03","2019-01-04","2019-01-07","2019-01-08","2019-01-09","2019-01-10","2019-01-11","2019-01-14","2019-01-15","2019-01-16","2019-01-17","2019-01-18","2019-01-21","2019-01-22","2019-01-23","2019-01-24","2019-01-25","2019-01-28","2019-01-29","2019-01-30","2019-01-31","2019-02-01","2019-02-04","2019-02-05",
# ...

# %%
plyo.iplot(
 df[['a', 'b']].iplot(asFigure=True,
 theme='polar',
 title='A Time Series Plot',
 xTitle='date',
 yTitle='value',
 mode={'a': 'markers', 'b': 'lines+markers'},
 symbol={'a': 'circle', 'b': 'diamond'},
 size=3.5,
 colors={'a': 'blue', 'b': 'magenta'},
 ),
 image='png',
 filename='ply_02'
)
# Out:
# <div>                            <div id="cee7bd87-0be6-49d0-b483-ae24fe68c6ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cee7bd87-0be6-49d0-b483-ae24fe68c6ef")) {                    Plotly.newPlot(                        "cee7bd87-0be6-49d0-b483-ae24fe68c6ef",                        [{"line":{"color":"blue","dash":"solid","shape":"linear","width":1.3},"marker":{"size":3.5,"symbol":"circle"},"mode":"markers","name":"a","text":"","x":["2019-01-01","2019-01-02","2019-01-03","2019-01-04","2019-01-07","2019-01-08","2019-01-09","2019-01-10","2019-01-11","2019-01-14","2019-01-15","2019-01-16","2019-01-17","2019-01-18","2019-01-21","2019-01-22","2019-01-23","2019-01-24","2019-01-25","2019-01-28","2019-01-29","2019-01-30","2019-01-31","2019-02-01","20
# ...

# %% [markdown]
# Similar to matplotlib, plotly allows for a number of different plotting types. Plotting types available via Cufflinks are chart, scatter, bar, box, spread, ratio, heat map, surface, histogram, bubble, bubble3d, scatter3d, scattergeo, ohlc, candle,
# pie, and choropleth.

# %%
# Histogram example
plyo.iplot(
 df.iplot(kind='hist',  # Specifies the plotting type
 subplots=True,         # Requires separate subplots for every column
 bins=15,               # Sets the bins parameter (buckets to be used = bars to be plotted)
 asFigure=True),
 image='png',
 filename='ply_03'
 )
# Out:
# <div>                            <div id="134f0c49-cfba-41ce-a9a1-fbfb926cd099" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("134f0c49-cfba-41ce-a9a1-fbfb926cd099")) {                    Plotly.newPlot(                        "134f0c49-cfba-41ce-a9a1-fbfb926cd099",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"a","nbinsx":15,"opacity":0.8,"orientation":"v","x":[109.03753455480783,107.59824230810597,101.63966756508827,98.50036328156196,93.94163220043531,95.88196563133792,86.87085895530836,79.6111008261501,69.37736388555813,73.52520363735977,81.50297131699034,72.66844845921652,72.91190545281164,73.09276367149346,67.00511655560008,69.25895688579352
# ...

# %% [markdown]
# ### Finacial Plots

# %% [markdown]
# This subsection uses a real financial data set, time series data for the EUR/USD exchange rate (source: FXCM Forex Capital Markets Ltd.)

# %%
# Import the data
raw = pd.read_csv('../source/fxcm_eur_usd_eod_data.csv', index_col=0, parse_dates=True)

# Print first few rows
raw.head()
# Out:
#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# 2013-01-01 22:00:00  1.31848  1.32935  1.31563   1.31850  1.31853  1.32940
# 2013-01-02 22:00:00  1.31850  1.31903  1.30468   1.30483  1.31860  1.31910
# 2013-01-03 22:00:00  1.30483  1.30897  1.29974   1.30679  1.30501  1.30898
# 2013-01-06 22:00:00  1.30679  1.31194  1.30168   1.31159  1.30697  1.31196
# 2013-01-07 22:00:00  1.31159  1.31398  1.30563   1.30805  1.31166  1.31400
#
#                       AskLow  AskClose
# 2013-01-01 22:00:00  1.31571   1.31860
# 2013-01-02 22:00:00  1.30471   1.30501
# 2013-01-03 22:00:00  1.29978   1.30697
# 2013-01-06 22:00:00  1.30168   1.31166
# 2013-01-07 22:00:00  1.30565   1.30815

# %%
# View data information to look for any missing values
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1547 entries, 2013-01-01 22:00:00 to 2017-12-31 22:00:00
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BidOpen   1547 non-null   float64
#  1   BidHigh   1547 non-null   float64
#  2   BidLow    1547 non-null   float64
#  3   BidClose  1547 non-null   float64
#  4   AskOpen   1547 non-null   float64
#  5   AskHigh   1547 non-null   float64
#  6   AskLow    1547 non-null   float64
#  7   AskClose  1547 non-null   float64
# dtypes: float64(8)
# memory usage: 108.8 KB

# %%
# We take the relevant columns and display only the last 60 rows for visualization
quotes = raw[['AskOpen', 'AskHigh', 'AskLow', 'AskClose']]
quotes = quotes.iloc[-60:]
quotes.tail()
# Out:
#                      AskOpen  AskHigh   AskLow  AskClose
# 2017-12-25 22:00:00  1.18667  1.18791  1.18467   1.18587
# 2017-12-26 22:00:00  1.18587  1.19104  1.18552   1.18885
# 2017-12-27 22:00:00  1.18885  1.19592  1.18885   1.19426
# 2017-12-28 22:00:00  1.19426  1.20256  1.19369   1.20092
# 2017-12-31 22:00:00  1.20092  1.20144  1.19994   1.20144

# %%
# QuantFig object takes the DataFrame object as input and allows for some basic customization
qf = cf.QuantFig(
 quotes,
 title='EUR/USD Exchange Rate',
 legend='top',
 name='EUR/USD'
 )

# Then with qf.iplot() we plot the data
plyo.iplot(
 qf.iplot(asFigure=True),
 image='png',
 filename='qf_01'
 )
# Out:
# <div>                            <div id="9ee0c9c3-27af-4a92-9650-32eb3a4cfac6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ee0c9c3-27af-4a92-9650-32eb3a4cfac6")) {                    Plotly.newPlot(                        "9ee0c9c3-27af-4a92-9650-32eb3a4cfac6",                        [{"close":[1.17822,1.17655,1.17495,1.17622,1.18132,1.16505,1.16127,1.1614,1.16509,1.16465,1.1619700000000002,1.16586,1.16111,1.16181,1.1611200000000002,1.1587,1.15964,1.1642,1.16665,1.16603,1.1667299999999998,1.1798,1.17918,1.17707,1.17948,1.17893,1.17326,1.17382,1.1823,1.1852200000000002,1.19368,1.19296,1.18985,1.18428,1.1847299999999998,1.1904,1.1902,1.18646,1.18667,1.18264,1.17961,1.1773,1.17772,1.17671,1.17689,1.17421,1.18261,1.17784,1.17543,1.17467,1.17823,1.
# ...

# %%
# We can add typical financial charting elements, such as Bollinger bands
qf.add_bollinger_bands(periods=15 # The number of periods for the Bollinger band.
                       ,boll_std=2) # The number of standard deviations to be used for the band width

plyo.iplot(qf.iplot(asFigure=True),
 image='png',
 filename='qf_02'
 )
# Out:
# <div>                            <div id="f9c0c418-7936-4720-8e05-f71c8685c0ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9c0c418-7936-4720-8e05-f71c8685c0ee")) {                    Plotly.newPlot(                        "f9c0c418-7936-4720-8e05-f71c8685c0ee",                        [{"legendgroup":"BOLL(AskClose,15)","line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"BOLL(AskClose,15)","showlegend":true,"text":"","x":["2017-10-19 21:00:00","2017-10-21 21:00:00","2017-10-22 21:00:00","2017-10-23 21:00:00","2017-10-24 21:00:00","2017-10-25 21:00:00","2017-10-26 21:00:00","2017-10-28 21:00:00","2017-10-29 21:00:00","2017-10-30 21:00:00","2017-10-31 21:00:00","2017-11-01 21:00:00","2017-
# ...

# %%
# We can also add certain financial indicators, such as RSI as subplots
qf.add_rsi(periods=14,
           showbands=False)

plyo.iplot(
 qf.iplot(asFigure=True),
 image='png',
 filename='qf_03'
)
# Out:
# <div>                            <div id="8307c081-f4d7-4446-b812-8842235132be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8307c081-f4d7-4446-b812-8842235132be")) {                    Plotly.newPlot(                        "8307c081-f4d7-4446-b812-8842235132be",                        [{"legendgroup":"BOLL(AskClose,15)","line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"BOLL(AskClose,15)","showlegend":true,"text":"","x":["2017-10-19 21:00:00","2017-10-21 21:00:00","2017-10-22 21:00:00","2017-10-23 21:00:00","2017-10-24 21:00:00","2017-10-25 21:00:00","2017-10-26 21:00:00","2017-10-28 21:00:00","2017-10-29 21:00:00","2017-10-30 21:00:00","2017-10-31 21:00:00","2017-11-01 21:00:00","2017-
# ...

# %% [markdown]
# The relative strength index (RSI) is a momentum indicator used in technical analysis. RSI measures the speed and magnitude of a security's recent price changes to evaluate overvalued or undervalued conditions in the price of that security. Generally, when the RSI indicator crosses 30 on the RSI chart, it is a bullish sign and when it crosses 70, it is a bearish sign.
